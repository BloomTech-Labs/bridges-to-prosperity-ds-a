# %%
import pandas as pd
df_main = pd.read_csv('/Users/jasimrashid/Projects/DS-Unit-6-Labs/Labs27-A-Bridges_to_Prosperity-DS/EDA/main_20201016.csv')

# %%
pd.set_option('display.max_columns',100)
df_main.head()
# Out:
#    Unnamed: 0 country          province district  district_id  \
# 0           0  Rwanda  Western Province   Rusizi           36
# 1           1  Rwanda  Western Province   Rusizi           36
# 2           2  Rwanda  Western Province   Rusizi           36
# 3           3  Rwanda  Western Province   Rusizi           36
# 4           4  Rwanda  Western Province   Rusizi           36
#
#             sector  sector_id              cell   cell_id  village  \
# 0           Giheke     3605.0          Gakomeye  360502.0     Buzi
# 1           Giheke     3605.0          Gakomeye  360502.0     Buzi
# 2         Bugarama     3601.0            Nyange  360101.0   Rusayo
# 3  Giheke-Bushenge     3605.0  Gakomeye-Gasheke  360502.0  Gacyamo
# 4           Butare     3602.0          Rwambogo  360204.0   Gasumo
#
#    village_id  village_lat  village_long  distance_village_to_health_center  \
# 0  36050201.0          NaN           NaN                                NaN
# 1  36050201.0          NaN           NaN                                NaN
# 2  36010113.0          NaN           NaN                                NaN
# 3  36050202.0          NaN           NaN                                NaN
# 4  36020406.0          NaN           NaN                                NaN
#
#    population_per_village        name project_code        type     stage  \
# 0                     NaN        Buzi      1014107   Suspended  Rejected
# 1                     NaN   Kamigisha      1014106   Suspended  Rejected
# 2                     NaN      Rusayo      1007661  Suspension  Rejected
# 3                     NaN     Gacyamo      1014108  Suspension  Rejected
# 4                     NaN  Nyagatango      1014109   Suspended  Rejected
#
#    sub_stage  individuals_directly_served  span       lat       long  \
# 0  Technical                            0     0 -2.420560  28.966200
# 1  Technical                            0     0 -2.424860  28.957260
# 2  Technical                        17270    25 -2.697308  29.029517
# 3  Technical                            0     0 -2.418550  28.969460
# 4  Technical                            0     0 -2.588680  29.112470
#
#    population_per_bridge  distance_bridge_to_health_center community_served_1  \
# 0                    NaN                               NaN               Buzi
# 1                    NaN                               NaN             Kabuga
# 2                    NaN                               NaN          Pera cell
# 3                    NaN                               NaN            Gacyamo
# 4                    NaN                               NaN             Gasumo
#
#    community_served_1_id community_served_2  community_served_2_id  \
# 0             36050201.0             Kabuga             36050203.0
# 1             36050203.0               Buzi             36050201.0
# 2               360102.0        Kizura cell                    NaN
# 3             36050202.0               Buzi             36050201.0
# 4             36020406.0              Kenya                    NaN
#
#   community_served_3  community_served_3_id community_served_4  \
# 0           Kagarama             36050204.0            Gacyamo
# 1  Gacyamo - Gasheke             36050202.0           Kagarama
# 2                NaN                    NaN                NaN
# 3             Kabuga             36050203.0           Kagarama
# 4         Ndengerezi                    NaN           Rushwati
#
#    community_served_4_id community_served_5  community_served_5_id  \
# 0             36050202.0            Gasheke                    NaN
# 1             36050204.0             Kanoga                    NaN
# 2                    NaN                NaN                    NaN
# 3             36050204.0            Gasheke                    NaN
# 4                    NaN                NaN                    NaN
#
#                               form        case_safe_id   opportunity_id  \
# 0  Project Assessment - 2018.10.29  a1if1000002e51bAAA  006f100000d1fk1
# 1  Project Assessment - 2018.10.29  a1if1000002e51WAAQ  006f100000d1fjw
# 2  Project Assessment - 2018.12.13  a1if1000002qz1JAAQ  006f100000a86ID
# 3  Project Assessment - 2018.10.29  a1if1000002e51gAAA  006f100000d1fk6
# 4  Project Assessment - 2018.10.29  a1if1000002e51lAAA  006f100000d1fkB
#
#               adm1_name adm2_name  agro - crop&livestock  \
# 0  $West/Iburengerazuba   $Rusizi               8.716393
# 1  $West/Iburengerazuba   $Rusizi               8.716393
# 2  $West/Iburengerazuba   $Rusizi               8.716393
# 3  $West/Iburengerazuba   $Rusizi               8.716393
# 4  $West/Iburengerazuba   $Rusizi               8.716393
#
#    agro - food&cash crop  agrocmrc - trade/wholesale  \
# 0              66.023214                    3.637643
# 1              66.023214                    3.637643
# 2              66.023214                    3.637643
# 3              66.023214                    3.637643
# 4              66.023214                    3.637643
#
#    commerce - business/trading  commerce - petty trade  \
# 0                      1.73183                3.754816
# 1                      1.73183                3.754816
# 2                      1.73183                3.754816
# 3                      1.73183                3.754816
# 4                      1.73183                3.754816
#
#    labor - artisan/skilled  labor - daily/unskilled - agro     other  \
# 0                 1.315136                       12.790276  2.030692
# 1                 1.315136                       12.790276  2.030692
# 2                 1.315136                       12.790276  2.030692
# 3                 1.315136                       12.790276  2.030692
# 4                 1.315136                       12.790276  2.030692
#
#    gender_parity_index_for_net_primary_school_attendance  \
# 0                                               1.02
# 1                                               1.02
# 2                                               1.02
# 3                                               1.02
# 4                                               1.02
#
#    gender_parity_index_for_net_secondary_school_attendance  \
# 0                                               1.33
# 1                                               1.33
# 2                                               1.33
# 3                                               1.33
# 4                                               1.33
#
#    households with electricity  infant mortality rate  \
# 0                         19.5                   41.0
# 1                         19.5                   41.0
# 2                         19.5                   41.0
# 3                         19.5                   41.0
# 4                         19.5                   41.0
#
#    malaria_prevalence_according_to_rdt  \
# 0                                  2.4
# 1                                  2.4
# 2                                  2.4
# 3                                  2.4
# 4                                  2.4
#
#    net_primary_school_attendance_rate_female  \
# 0                                       92.8
# 1                                       92.8
# 2                                       92.8
# 3                                       92.8
# 4                                       92.8
#
#    net_primary_school_attendance_rate_male  \
# 0                                     91.1
# 1                                     91.1
# 2                                     91.1
# 3                                     91.1
# 4                                     91.1
#
#    net_primary_school_attendance_rate_total  under_five_mortality_rate  \
# 0                                      92.0                       62.0
# 1                                      92.0                       62.0
# 2                                      92.0                       62.0
# 3                                      92.0                       62.0
# 4                                      92.0                       62.0
#
#    women_who_are_literate  women_with_secondary_or_higher_education
# 0                    77.9                                      21.7
# 1                    77.9                                      21.7
# 2                    77.9                                      21.7
# 3                    77.9                                      21.7
# 4                    77.9                                      21.7

# %%
# temp - use Josh's population
df_projects_population = pd.read_csv('/Users/jasimrashid/Projects/DS-Unit-6-Labs/Labs27-A-Bridges_to_Prosperity-DS/EDA/projects_population.csv')
df_main = pd.merge(df_main,df_projects_population[['project_code','Population']], on='project_code')
df_main
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.
#       Unnamed: 0 country          province district  district_id  \
# 0              0  Rwanda  Western Province   Rusizi           36
# 1              1  Rwanda  Western Province   Rusizi           36
# 2              2  Rwanda  Western Province   Rusizi           36
# 3              3  Rwanda  Western Province   Rusizi           36
# 4              4  Rwanda  Western Province   Rusizi           36
# ...          ...     ...               ...      ...          ...
# 1391        1418  Rwanda  Eastern Province  Kayonza           54
# 1392        1419  Rwanda  Eastern Province  Kayonza           54
# 1393        1420  Rwanda  Eastern Province  Kayonza           54
# 1394        1421  Rwanda  Eastern Province  Kayonza           54
# 1395        1422  Rwanda  Eastern Province  Kayonza           54
#
#                sector  sector_id              cell   cell_id      village  \
# 0              Giheke     3605.0          Gakomeye  360502.0         Buzi
# 1              Giheke     3605.0          Gakomeye  360502.0         Buzi
# 2            Bugarama     3601.0            Nyange  360101.0       Rusayo
# 3     Giheke-Bushenge     3605.0  Gakomeye-Gasheke  360502.0      Gacyamo
# 4              Butare     3602.0          Rwambogo  360204.0       Gasumo
# ...               ...        ...               ...       ...          ...
# 1391            Mwiri     5407.0            Migera  540702.0       Murori
# 1392           Kabare     5402.0            Gitara  540202.0     Kazeneza
# 1393  Rwinkwavu-Mwili     5407.0         Nyamugari  540703.0  Gasarabwayi
# 1394           Kabare     5402.0         Cyarubare  540201.0    Rwabarema
# 1395            Mwiri     5407.0         Nyamugari  540703.0       Kabeza
#
#       village_id  village_lat  village_long  \
# 0     36050201.0          NaN           NaN
# 1     36050201.0          NaN           NaN
# 2     36010113.0          NaN           NaN
# 3     36050202.0          NaN           NaN
# 4     36020406.0          NaN           NaN
# ...          ...          ...           ...
# 1391  54070202.0          NaN           NaN
# 1392  54020204.0          NaN           NaN
# 1393  54070301.0          NaN           NaN
# 1394  54020109.0          NaN           NaN
# 1395  54070302.0          NaN           NaN
#
#       distance_village_to_health_center  population_per_village         name  \
# 0                                   NaN                     NaN         Buzi
# 1                                   NaN                     NaN    Kamigisha
# 2                                   NaN                     NaN       Rusayo
# 3                                   NaN                     NaN      Gacyamo
# 4                                   NaN                     NaN   Nyagatango
# ...                                 ...                     ...          ...
# 1391                                NaN                     NaN       Murori
# 1392                                NaN                     NaN     Kazeneza
# 1393                                NaN                     NaN  Gasarabwayi
# 1394                                NaN                     NaN      Mutembo
# 1395                                NaN                     NaN       Kabeza
#
#      project_code        type     stage  sub_stage  \
# 0         1014107   Suspended  Rejected  Technical
# 1         1014106   Suspended  Rejected  Technical
# 2         1007661  Suspension  Rejected  Technical
# 3         1014108  Suspension  Rejected  Technical
# 4         1014109   Suspended  Rejected  Technical
# ...           ...         ...       ...        ...
# 1391      1013697  Suspension  Rejected  Technical
# 1392      1013706  Suspension  Rejected  Technical
# 1393      1007393  Suspension  Rejected  Technical
# 1394      1013705       Other  Rejected  Technical
# 1395      1013704  Suspension  Rejected  Technical
#
#       individuals_directly_served  span       lat       long  \
# 0                               0     0 -2.420560  28.966200
# 1                               0     0 -2.424860  28.957260
# 2                           17270    25 -2.697308  29.029517
# 3                               0     0 -2.418550  28.969460
# 4                               0     0 -2.588680  29.112470
# ...                           ...   ...       ...        ...
# 1391                            0     0 -1.911180  30.560470
# 1392                            0     0 -2.066860  30.625240
# 1393                            0    15 -1.905030  30.601910
# 1394                            0     0 -1.964560  30.661150
# 1395                            0     0 -1.890130  30.611390
#
#       population_per_bridge  distance_bridge_to_health_center  \
# 0                       NaN                               NaN
# 1                       NaN                               NaN
# 2                       NaN                               NaN
# 3                       NaN                               NaN
# 4                       NaN                               NaN
# ...                     ...                               ...
# 1391                    NaN                               NaN
# 1392                    NaN                               NaN
# 1393                    NaN                               NaN
# 1394                    NaN                               NaN
# 1395                    NaN                               NaN
#
#      community_served_1  community_served_1_id community_served_2  \
# 0                  Buzi             36050201.0             Kabuga
# 1                Kabuga             36050203.0               Buzi
# 2             Pera cell               360102.0        Kizura cell
# 3               Gacyamo             36050202.0               Buzi
# 4                Gasumo             36020406.0              Kenya
# ...                 ...                    ...                ...
# 1391             Murori             54070202.0          Kirambo 1
# 1392           Kazeneza             54020204.0            Rugunga
# 1393        Gasarabwayi             54070301.0           Uburembo
# 1394            Mutembo             54020109.0          Rwabarema
# 1395             Kabeza             54070302.0           Kigarama
#
#       community_served_2_id community_served_3  community_served_3_id  \
# 0                36050203.0           Kagarama             36050204.0
# 1                36050201.0  Gacyamo - Gasheke             36050202.0
# 2                       NaN                NaN                    NaN
# 3                36050201.0             Kabuga             36050203.0
# 4                       NaN         Ndengerezi                    NaN
# ...                     ...                ...                    ...
# 1391                    NaN         Nyabisindu                    NaN
# 1392             54020206.0                NaN                    NaN
# 1393                    NaN            Rugunga                    NaN
# 1394             54020109.0           Umuyenzi             54020113.0
# 1395             54070304.0        Gasarabwayi             54070301.0
#
#      community_served_4  community_served_4_id community_served_5  \
# 0               Gacyamo             36050202.0            Gasheke
# 1              Kagarama             36050204.0             Kanoga
# 2                   NaN                    NaN                NaN
# 3              Kagarama             36050204.0            Gasheke
# 4              Rushwati                    NaN                NaN
# ...                 ...                    ...                ...
# 1391                NaN                    NaN                NaN
# 1392                NaN                    NaN                NaN
# 1393             Kabeza             54070302.0                NaN
# 1394                NaN                    NaN                NaN
# 1395                NaN                    NaN                NaN
#
#       community_served_5_id                             form  \
# 0                       NaN  Project Assessment - 2018.10.29
# 1                       NaN  Project Assessment - 2018.10.29
# 2                       NaN  Project Assessment - 2018.12.13
# 3                       NaN  Project Assessment - 2018.10.29
# 4                       NaN  Project Assessment - 2018.10.29
# ...                     ...                              ...
# 1391                    NaN   Project Assessment - 2018.9.28
# 1392                    NaN   Project Assessment - 2018.9.28
# 1393                    NaN   Project Assessment - 2018.9.28
# 1394                    NaN   Project Assessment - 2018.9.28
# 1395                    NaN   Project Assessment - 2018.9.28
#
#             case_safe_id   opportunity_id             adm1_name adm2_name  \
# 0     a1if1000002e51bAAA  006f100000d1fk1  $West/Iburengerazuba   $Rusizi
# 1     a1if1000002e51WAAQ  006f100000d1fjw  $West/Iburengerazuba   $Rusizi
# 2     a1if1000002qz1JAAQ  006f100000a86ID  $West/Iburengerazuba   $Rusizi
# 3     a1if1000002e51gAAA  006f100000d1fk6  $West/Iburengerazuba   $Rusizi
# 4     a1if1000002e51lAAA  006f100000d1fkB  $West/Iburengerazuba   $Rusizi
# ...                  ...              ...                   ...       ...
# 1391  a1if1000002YtFJAA0  006f100000d7jB7              #Kibungo  #Kayonza
# 1392  a1if1000002YtWZAA0  006f100000d7jCy              #Kibungo  #Kayonza
# 1393  a1if1000002YtJ1AAK  006f100000a86Dt              #Kibungo  #Kayonza
# 1394  a1if1000002YtWFAA0  006f100000d7jCt              #Kibungo  #Kayonza
# 1395  a1if1000002YtTBAA0  006f100000d7jCe              #Kibungo  #Kayonza
#
#       agro - crop&livestock  agro - food&cash crop  \
# 0                  8.716393              66.023214
# 1                  8.716393              66.023214
# 2                  8.716393              66.023214
# 3                  8.716393              66.023214
# 4                  8.716393              66.023214
# ...                     ...                    ...
# 1391               4.672437              50.542219
# 1392               4.672437              50.542219
# 1393               4.672437              50.542219
# 1394               4.672437              50.542219
# 1395               4.672437              50.542219
#
#       agrocmrc - trade/wholesale  commerce - business/trading  \
# 0                       3.637643                     1.731830
# 1                       3.637643                     1.731830
# 2                       3.637643                     1.731830
# 3                       3.637643                     1.731830
# 4                       3.637643                     1.731830
# ...                          ...                          ...
# 1391                    5.692345                     1.190252
# 1392                    5.692345                     1.190252
# 1393                    5.692345                     1.190252
# 1394                    5.692345                     1.190252
# 1395                    5.692345                     1.190252
#
#       commerce - petty trade  labor - artisan/skilled  \
# 0                   3.754816                 1.315136
# 1                   3.754816                 1.315136
# 2                   3.754816                 1.315136
# 3                   3.754816                 1.315136
# 4                   3.754816                 1.315136
# ...                      ...                      ...
# 1391                3.229973                 1.996367
# 1392                3.229973                 1.996367
# 1393                3.229973                 1.996367
# 1394                3.229973                 1.996367
# 1395                3.229973                 1.996367
#
#       labor - daily/unskilled - agro     other  \
# 0                          12.790276  2.030692
# 1                          12.790276  2.030692
# 2                          12.790276  2.030692
# 3                          12.790276  2.030692
# 4                          12.790276  2.030692
# ...                              ...       ...
# 1391                       23.586532  9.089875
# 1392                       23.586532  9.089875
# 1393                       23.586532  9.089875
# 1394                       23.586532  9.089875
# 1395                       23.586532  9.089875
#
#       gender_parity_index_for_net_primary_school_attendance  \
# 0                                                  1.02
# 1                                                  1.02
# 2                                                  1.02
# 3                                                  1.02
# 4                                                  1.02
# ...                                                 ...
# 1391                                               1.01
# 1392                                               1.01
# 1393                                               1.01
# 1394                                               1.01
# 1395                                               1.01
#
#       gender_parity_index_for_net_secondary_school_attendance  \
# 0                                                  1.33
# 1                                                  1.33
# 2                                                  1.33
# 3                                                  1.33
# 4                                                  1.33
# ...                                                 ...
# 1391                                               1.01
# 1392                                               1.01
# 1393                                               1.01
# 1394                                               1.01
# 1395                                               1.01
#
#       households with electricity  infant mortality rate  \
# 0                            19.5                   41.0
# 1                            19.5                   41.0
# 2                            19.5                   41.0
# 3                            19.5                   41.0
# 4                            19.5                   41.0
# ...                           ...                    ...
# 1391                         19.5                   51.0
# 1392                         19.5                   51.0
# 1393                         19.5                   51.0
# 1394                         19.5                   51.0
# 1395                         19.5                   51.0
#
#       malaria_prevalence_according_to_rdt  \
# 0                                     2.4
# 1                                     2.4
# 2                                     2.4
# 3                                     2.4
# 4                                     2.4
# ...                                   ...
# 1391                                 15.5
# 1392                                 15.5
# 1393                                 15.5
# 1394                                 15.5
# 1395                                 15.5
#
#       net_primary_school_attendance_rate_female  \
# 0                                          92.8
# 1                                          92.8
# 2                                          92.8
# 3                                          92.8
# 4                                          92.8
# ...                                         ...
# 1391                                       92.6
# 1392                                       92.6
# 1393                                       92.6
# 1394                                       92.6
# 1395                                       92.6
#
#       net_primary_school_attendance_rate_male  \
# 0                                        91.1
# 1                                        91.1
# 2                                        91.1
# 3                                        91.1
# 4                                        91.1
# ...                                       ...
# 1391                                     91.8
# 1392                                     91.8
# 1393                                     91.8
# 1394                                     91.8
# 1395                                     91.8
#
#       net_primary_school_attendance_rate_total  under_five_mortality_rate  \
# 0                                         92.0                       62.0
# 1                                         92.0                       62.0
# 2                                         92.0                       62.0
# 3                                         92.0                       62.0
# 4                                         92.0                       62.0
# ...                                        ...                        ...
# 1391                                      92.2                       86.0
# 1392                                      92.2                       86.0
# 1393                                      92.2                       86.0
# 1394                                      92.2                       86.0
# 1395                                      92.2                       86.0
#
#       women_who_are_literate  women_with_secondary_or_higher_education  \
# 0                       77.9                                      21.7
# 1                       77.9                                      21.7
# 2                       77.9                                      21.7
# 3                       77.9                                      21.7
# 4                       77.9                                      21.7
# ...                      ...                                       ...
# 1391                    76.3                                      18.0
# 1392                    76.3                                      18.0
# 1393                    76.3                                      18.0
# 1394                    76.3                                      18.0
# 1395                    76.3                                      18.0
#
#        Population
# 0       369.10581
# 1       383.07240
# 2      2957.71255
# 3      2801.08794
# 4       921.28806
# ...           ...
# 1391   1331.07146
# 1392   2298.86884
# 1393  22863.03037
# 1394  12224.65494
# 1395  19252.13450
#
# [1396 rows x 61 columns]

# %%
df_temp = df_main[['province','district','stage','agro - crop&livestock','agro - food&cash crop','agrocmrc - trade/wholesale','commerce - business/trading','commerce - petty trade','labor - artisan/skilled','labor - daily/unskilled - agro','Population']]
df_temp.head()
# Out:
#            province district     stage  agro - crop&livestock  \
# 0  Western Province   Rusizi  Rejected               8.716393
# 1  Western Province   Rusizi  Rejected               8.716393
# 2  Western Province   Rusizi  Rejected               8.716393
# 3  Western Province   Rusizi  Rejected               8.716393
# 4  Western Province   Rusizi  Rejected               8.716393
#
#    agro - food&cash crop  agrocmrc - trade/wholesale  \
# 0              66.023214                    3.637643
# 1              66.023214                    3.637643
# 2              66.023214                    3.637643
# 3              66.023214                    3.637643
# 4              66.023214                    3.637643
#
#    commerce - business/trading  commerce - petty trade  \
# 0                      1.73183                3.754816
# 1                      1.73183                3.754816
# 2                      1.73183                3.754816
# 3                      1.73183                3.754816
# 4                      1.73183                3.754816
#
#    labor - artisan/skilled  labor - daily/unskilled - agro  Population
# 0                 1.315136                       12.790276   369.10581
# 1                 1.315136                       12.790276   383.07240
# 2                 1.315136                       12.790276  2957.71255
# 3                 1.315136                       12.790276  2801.08794
# 4                 1.315136                       12.790276   921.28806

# %%
df_temp['income_total'] = df_temp['agro - crop&livestock']+df_temp['agro - food&cash crop']+df_temp['agrocmrc - trade/wholesale']+df_temp['commerce - business/trading']+df_temp['commerce - petty trade']+df_temp['labor - artisan/skilled']+df_temp['labor - daily/unskilled - agro']
df_temp
# Out:
#               province district     stage  agro - crop&livestock  \
# 0     Western Province   Rusizi  Rejected               8.716393
# 1     Western Province   Rusizi  Rejected               8.716393
# 2     Western Province   Rusizi  Rejected               8.716393
# 3     Western Province   Rusizi  Rejected               8.716393
# 4     Western Province   Rusizi  Rejected               8.716393
# ...                ...      ...       ...                    ...
# 1391  Eastern Province  Kayonza  Rejected               4.672437
# 1392  Eastern Province  Kayonza  Rejected               4.672437
# 1393  Eastern Province  Kayonza  Rejected               4.672437
# 1394  Eastern Province  Kayonza  Rejected               4.672437
# 1395  Eastern Province  Kayonza  Rejected               4.672437
#
#       agro - food&cash crop  agrocmrc - trade/wholesale  \
# 0                 66.023214                    3.637643
# 1                 66.023214                    3.637643
# 2                 66.023214                    3.637643
# 3                 66.023214                    3.637643
# 4                 66.023214                    3.637643
# ...                     ...                         ...
# 1391              50.542219                    5.692345
# 1392              50.542219                    5.692345
# 1393              50.542219                    5.692345
# 1394              50.542219                    5.692345
# 1395              50.542219                    5.692345
#
#       commerce - business/trading  commerce - petty trade  \
# 0                        1.731830                3.754816
# 1                        1.731830                3.754816
# 2                        1.731830                3.754816
# 3                        1.731830                3.754816
# 4                        1.731830                3.754816
# ...                           ...                     ...
# 1391                     1.190252                3.229973
# 1392                     1.190252                3.229973
# 1393                     1.190252                3.229973
# 1394                     1.190252                3.229973
# 1395                     1.190252                3.229973
#
#       labor - artisan/skilled  labor - daily/unskilled - agro   Population  \
# 0                    1.315136                       12.790276    369.10581
# 1                    1.315136                       12.790276    383.07240
# 2                    1.315136                       12.790276   2957.71255
# 3                    1.315136                       12.790276   2801.08794
# 4                    1.315136                       12.790276    921.28806
# ...                       ...                             ...          ...
# 1391                 1.996367                       23.586532   1331.07146
# 1392                 1.996367                       23.586532   2298.86884
# 1393                 1.996367                       23.586532  22863.03037
# 1394                 1.996367                       23.586532  12224.65494
# 1395                 1.996367                       23.586532  19252.13450
#
#       income_total
# 0        97.969308
# 1        97.969308
# 2        97.969308
# 3        97.969308
# 4        97.969308
# ...            ...
# 1391     90.910125
# 1392     90.910125
# 1393     90.910125
# 1394     90.910125
# 1395     90.910125
#
# [1396 rows x 12 columns]

# %%
result_1 = pd.pivot_table(df_temp,values='agro - food&cash crop',columns='stage',index='province')
result_2 = pd.pivot_table(df_temp,values='agro - crop&livestock',columns='stage',index='province')
result_3 = pd.pivot_table(df_temp,values='agrocmrc - trade/wholesale',columns='stage',index='province')
result_4 = pd.pivot_table(df_temp,values='commerce - business/trading',columns='stage',index='province')
result_5 = pd.pivot_table(df_temp,values='commerce - petty trade',columns='stage',index='province')
result_6 = pd.pivot_table(df_temp,values='labor - artisan/skilled',columns='stage',index='province')
result_7 = pd.pivot_table(df_temp,values='labor - daily/unskilled - agro',columns='stage',index='province')

# %%
result_8 = pd.pivot_table(df_temp,values='income_total',columns='stage',index='province')
result_9 = pd.pivot_table(df_temp,values='Population',columns='stage',index='province')

# %%
import seaborn as sns

# %%
result
# Out:
# stage               Complete  Confirmed  Identified  Prospecting   Rejected  \
# province
# Eastern Province         NaN        NaN   40.547894          NaN  52.461640
# Kigali             15.325222        NaN   15.325222          NaN  12.081630
# Northern Province        NaN        NaN   47.026136    59.855715  51.738708
# Southern Province  58.946034  49.230771   58.287331    49.230771  54.944335
# Western Province   44.236229  46.615226   45.624890    38.311893  47.802628
#
# stage              Under Construction
# province
# Eastern Province                  NaN
# Kigali                            NaN
# Northern Province                 NaN
# Southern Province           59.245426
# Western Province            68.391859

# %%
sns.heatmap(result_1, annot=True, fmt='g',cmap='viridis')

# %%
sns.heatmap(result_2, annot=True, fmt='g',cmap='viridis')

# %%
sns.heatmap(result_3, annot=True, fmt='g',cmap='viridis')

# %%
sns.heatmap(result_4, annot=True, fmt='g',cmap='viridis')

# %%
sns.heatmap(result_5, annot=True, fmt='g',cmap='viridis')

# %%
sns.heatmap(result_6, annot=True, fmt='g',cmap='viridis')

# %%
sns.heatmap(result_7, annot=True, fmt='g',cmap='viridis')

# %%
sns.heatmap(result_8, annot=True, fmt='g',cmap='viridis')

# %%
sns.heatmap(result_9, annot=True, fmt='g',cmap='viridis')

# %%
df_main.Population.sum()
# Out:
# 11609664.661539972

# %%
df_temp.corr()
# Out:
#                                 agro - crop&livestock  agro - food&cash crop  \
# agro - crop&livestock                        1.000000              -0.158524
# agro - food&cash crop                       -0.158524               1.000000
# agrocmrc - trade/wholesale                  -0.183166              -0.434273
# commerce - business/trading                 -0.246851              -0.570074
# commerce - petty trade                      -0.391446              -0.517592
# labor - artisan/skilled                     -0.225398              -0.375642
# labor - daily/unskilled - agro              -0.281945              -0.629652
#
#                                 agrocmrc - trade/wholesale  \
# agro - crop&livestock                            -0.183166
# agro - food&cash crop                            -0.434273
# agrocmrc - trade/wholesale                        1.000000
# commerce - business/trading                       0.064696
# commerce - petty trade                            0.157886
# labor - artisan/skilled                           0.074064
# labor - daily/unskilled - agro                    0.380827
#
#                                 commerce - business/trading  \
# agro - crop&livestock                             -0.246851
# agro - food&cash crop                             -0.570074
# agrocmrc - trade/wholesale                         0.064696
# commerce - business/trading                        1.000000
# commerce - petty trade                             0.730004
# labor - artisan/skilled                            0.433756
# labor - daily/unskilled - agro                     0.121687
#
#                                 commerce - petty trade  \
# agro - crop&livestock                        -0.391446
# agro - food&cash crop                        -0.517592
# agrocmrc - trade/wholesale                    0.157886
# commerce - business/trading                   0.730004
# commerce - petty trade                        1.000000
# labor - artisan/skilled                       0.511169
# labor - daily/unskilled - agro                0.179826
#
#                                 labor - artisan/skilled  \
# agro - crop&livestock                         -0.225398
# agro - food&cash crop                         -0.375642
# agrocmrc - trade/wholesale                     0.074064
# commerce - business/trading                    0.433756
# commerce - petty trade                         0.511169
# labor - artisan/skilled                        1.000000
# labor - daily/unskilled - agro                 0.090013
#
#                                 labor - daily/unskilled - agro
# agro - crop&livestock                                -0.281945
# agro - food&cash crop                                -0.629652
# agrocmrc - trade/wholesale                            0.380827
# commerce - business/trading                           0.121687
# commerce - petty trade                                0.179826
# labor - artisan/skilled                               0.090013
# labor - daily/unskilled - agro                        1.000000

# %%
sns.heatmap(df_temp.corr())

# %%
df_main_surveyed = df_main[df_main['individuals_directly_served']!=0]

# %%
df_temp_surveyed = df_main_surveyed[['province','district','stage','agro - crop&livestock','agro - food&cash crop','agrocmrc - trade/wholesale','commerce - business/trading','commerce - petty trade','labor - artisan/skilled','labor - daily/unskilled - agro','Population']]
df_temp_surveyed.head()
df_temp_surveyed['income_total'] = df_temp_surveyed['agro - crop&livestock']+df_temp_surveyed['agro - food&cash crop']+df_temp_surveyed['agrocmrc - trade/wholesale']+df_temp_surveyed['commerce - business/trading']+df_temp_surveyed['commerce - petty trade']+df_temp_surveyed['labor - artisan/skilled']+df_temp_surveyed['labor - daily/unskilled - agro']
df_temp_surveyed
result_10 = pd.pivot_table(df_temp_surveyed,values='Population',columns='stage',index='province')
result_11 = pd.pivot_table(df_temp_surveyed,values='income_total',columns='stage',index='province')

# %%
df_temp_surveyed
# Out:
#                province    district       stage  agro - crop&livestock  \
# 2      Western Province      Rusizi    Rejected               8.716393
# 106    Western Province      Rubavu    Complete               5.559486
# 277    Western Province     Rutsiro  Identified              13.870090
# 284    Western Province     Rutsiro    Rejected              13.870090
# 285    Western Province     Rutsiro  Identified              13.870090
# 286    Western Province     Rutsiro    Rejected              13.870090
# 287    Western Province     Rutsiro    Rejected              13.870090
# 288    Western Province     Rutsiro    Rejected              13.870090
# 289    Western Province     Rutsiro    Rejected              13.870090
# 434    Western Province     Nyabihu    Rejected               1.007911
# 509   Northern Province     Rulindo    Rejected              16.651847
# 751   Southern Province     Kamonyi    Rejected              14.528755
# 849   Southern Province     Muhanga    Complete               7.317987
# 993   Southern Province     Ruhango    Complete              23.036100
# 1006  Southern Province     Ruhango    Complete              23.036100
# 1023  Southern Province        Huye    Complete               3.422908
# 1024  Southern Province        Huye    Complete               3.422908
# 1169             Kigali  Nyarugenge  Identified               0.455348
# 1192   Eastern Province      Kirehe    Rejected              28.872728
# 1201   Eastern Province      Kirehe    Rejected              28.872728
# 1207   Eastern Province      Kirehe    Rejected              28.872728
#
#       agro - food&cash crop  agrocmrc - trade/wholesale  \
# 2                 66.023214                    3.637643
# 106               22.548419                   13.573917
# 277               44.533178                    2.752274
# 284               44.533178                    2.752274
# 285               44.533178                    2.752274
# 286               44.533178                    2.752274
# 287               44.533178                    2.752274
# 288               44.533178                    2.752274
# 289               44.533178                    2.752274
# 434               32.150263                   10.046850
# 509               35.028587                    0.615781
# 751               48.020059                    6.001212
# 849               78.407600                    1.629715
# 993               52.747524                    4.075744
# 1006              52.747524                    4.075744
# 1023              44.244612                    3.627016
# 1024              44.244612                    3.627016
# 1169              15.325222                    4.528377
# 1192              55.133631                    3.320417
# 1201              55.133631                    3.320417
# 1207              55.133631                    3.320417
#
#       commerce - business/trading  commerce - petty trade  \
# 2                        1.731830                3.754816
# 106                      4.623371                5.332477
# 277                      0.388700                2.106053
# 284                      0.388700                2.106053
# 285                      0.388700                2.106053
# 286                      0.388700                2.106053
# 287                      0.388700                2.106053
# 288                      0.388700                2.106053
# 289                      0.388700                2.106053
# 434                      2.543886                4.776823
# 509                      2.641860                3.079436
# 751                      1.982491                1.861244
# 849                      0.403797                0.445656
# 993                      3.838113                     NaN
# 1006                     3.838113                     NaN
# 1023                     6.172614                5.291680
# 1024                     6.172614                5.291680
# 1169                    18.330348               20.759084
# 1192                     1.264830                0.779173
# 1201                     1.264830                0.779173
# 1207                     1.264830                0.779173
#
#       labor - artisan/skilled  labor - daily/unskilled - agro   Population  \
# 2                    1.315136                       12.790276   2957.71255
# 106                  5.042172                       38.793541   4784.77158
# 277                  2.345845                       32.841147  14904.88124
# 284                  2.345845                       32.841147    687.76400
# 285                  2.345845                       32.841147  11702.81508
# 286                  2.345845                       32.841147   1529.04675
# 287                  2.345845                       32.841147   2754.55824
# 288                  2.345845                       32.841147  23213.49795
# 289                  2.345845                       32.841147  31928.89276
# 434                  1.639272                       44.900651   2600.24867
# 509                  1.624357                       32.271570   7468.64409
# 751                  0.314027                       24.993285   4310.60349
# 849                  0.427466                        7.847130   2803.50241
# 993                  0.806547                       15.144472   9897.65805
# 1006                 0.806547                       15.144472  11157.85377
# 1023                 4.064223                       31.036493   1888.05422
# 1024                 4.064223                       31.036493   5436.63421
# 1169                12.159040                       12.860004   6308.65126
# 1192                 2.044424                        5.883126   4754.33540
# 1201                 2.044424                        5.883126   4790.78602
# 1207                 2.044424                        5.883126  10179.95262
#
#       income_total
# 2        97.969308
# 106      95.473384
# 277      98.837286
# 284      98.837286
# 285      98.837286
# 286      98.837286
# 287      98.837286
# 288      98.837286
# 289      98.837286
# 434      97.065656
# 509      91.913438
# 751      97.701074
# 849      96.479351
# 993            NaN
# 1006           NaN
# 1023     97.859546
# 1024     97.859546
# 1169     84.417423
# 1192     97.298329
# 1201     97.298329
# 1207     97.298329

# %%
sns.heatmap(result_10, annot=True, fmt='g',cmap='viridis')

# %%
sns.heatmap(result_11, annot=True, fmt='g',cmap='viridis')

# %%
result_12 = pd.pivot_table(df_temp_surveyed,values='Population',columns='stage',index='district')
result_13 = pd.pivot_table(df_temp_surveyed,values='income_total',columns='stage',index='district')

# %%
sns.heatmap(result_12, annot=True, fmt='g',cmap='viridis')

# %%
sns.heatmap(result_13, annot=True, fmt='g',cmap='viridis')
